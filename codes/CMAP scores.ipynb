# %%
from utils import *

# %%
cmap = pd.read_csv('../data/cmap/output.antiviralSig.A549.csv')
cmap
# Out:
#       Rank   Score Type             ID                         Name  \
# 0        2  100.00   cp  BRD-A01320529                   salmeterol
# 1        3   99.99   cp  BRD-A70731303     avrainvillamide-analog-5
# 2       45   99.98   cp  BRD-A50157456                  terbutaline
# 3       46   99.98   cp  BRD-A65013509                   oxybutynin
# 4       47   99.98   cp  BRD-K78692225                  leflunomide
# ...    ...     ...  ...            ...                          ...
# 2390  7918  -99.98   cp  BRD-K92413528  thiazolidinecarboxylic-acid
# 2391  7919  -99.98   cp  BRD-K63430059                  methoxsalen
# 2392  7920  -99.98   cp  BRD-A68039575               liquiritigenin
# 2393  7921  -99.98   cp  BRD-A09925278                   etilefrine
# 2394  7978 -100.00   cp  BRD-A02759312                    betaxolol
#
#                                  Description  \
# 0                Adrenergic receptor agonist
# 1                    nucleophosmin inhibitor
# ...

# %%
sns.set(context='notebook', style='white', palette='deep', font='sans-serif', font_scale=1, color_codes=True)
import matplotlib as mpl

mpl.rc('figure', dpi=300)

fig,ax = plt.subplots(figsize=(4,2))
scores = cmap['Score'].values

# ax.hist(scores, bins=20)
ax.hist(scores[scores>90], bins=20)
ax.set_ylabel('Number of Candidates')
ax.set_xlabel('CMap Scores')
# Out:
# Text(0.5, 0, 'CMap Scores')
